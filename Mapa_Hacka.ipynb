# %%
## Instalando a biblioteca de dados Folium
# !pip install folium

# %%
## Importando as bibliotecas
import pandas as pd
import numpy as np
import folium as fl

# %%
## Baixando dataset com os locais de interesse
dataset = pd.read_csv('Dataset - Página1 (2).csv')

# %%
## Visualizando como está o dataset
dataset.head()
# Out:
#                            Instituição       CEP              Coordenadas  \
# 0  Organização de Voluntários de Goiás  74230130  -16.7203195,-49.2682233
# 1             Instituto Projeto Sonhar   5860080  -23.6641594,-46.7665536
# 2              São Mateus em Movimento   3960040   -23.595726,-46.4832402
# 3   Cursinho Popular Carolina de Jesus   5886490  -23.6798819,-46.7968357
# 4   Hospital Israelita Albert Einstein   5652900   -23.599396,-46.7247033
#
#                                         Ação social
# 0                         Distribuição de alimentos
# 1  Distribuição de alimentos, produtos de higiene...
# 2       Distribuição de itens de higiene e alimentos
# 3         Fundo para Mães e Trabalhadoras Informais
# 4  Distribuição de 50 milkits de produtos de higi...

# %%
## selecionar somente a coluna "Coordenadas" e "Instituição"
dataset.drop(['CEP'], axis = 1, inplace = True)

# %%
Local = dataset.iloc[:,0:2]

# %%
Local
# Out:
#                                           Instituição              Coordenadas
# 0                 Organização de Voluntários de Goiás  -16.7203195,-49.2682233
# 1                            Instituto Projeto Sonhar  -23.6641594,-46.7665536
# 2                             São Mateus em Movimento   -23.595726,-46.4832402
# 3                  Cursinho Popular Carolina de Jesus  -23.6798819,-46.7968357
# 4                  Hospital Israelita Albert Einstein   -23.599396,-46.7247033
# 5                          UNAS - Heliópolis e região  -23.6190666,-46.5926248
# 6              Associação de mulheres de Paraisópolis  -23.6207868,-46.7276768
# 7                    Habitat para a Humanidade Brasil  -23.5788393,-46.6477992
# 8                    Habitat para a Humanidade Brasil    -8.065735,-34.8916922
# 9   Associação de resgate à cidadania por amor à h...  -23.5529726,-46.6569627
# 10                                            Uneafro  -23.5532044,-46.6443476
# ...

# %%
## Montando o mapa
mapa = fl.Map(
    location=[-13.7014069,-69.7046912],
    zoom_start=4,
)

# %%
## Adicionando marcadores ao mapa

fl.Marker(
    location=[-16.7203195,-49.2682233],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Organizacao de Voluntarios de Goias)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.6641594,-46.7665536],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Instituto Projeto Sonhar)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.595726,-46.4832402],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Sao Mateus em Movimento)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.6798819,-46.7968357],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Cursinho Popular Carolina de Jesus)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.599396,-46.7247033],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Hospital Israelita Albert Einstein)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.6190666,-46.5926248],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(UNAS - Heliopolis e regiao)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[23.6207868,-46.7276768],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Associação de mulheres de Paraisopolis)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.6207868,-46.7276768],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Associacao de mulheres de Paraisopolis)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.5788393,-46.6477992],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Habitat para a Humanidade Brasil)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-8.065735,-34.8916922],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Habitat para a Humanidade Brasil)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.5529726,-46.6569627],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Associacao de resgate a cidadania por amor a humanidade)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.5532044,-46.6443476],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Uneafro)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[22.876358,-43.3435502],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Sesc Rio de Janeiro)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-22.8770779,-43.3363556],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Central Unica das Favelas)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)


fl.Marker(
    location=[-22.9837219,-43.2130625],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Instituto Phi)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[ -22.8551109,-43.2487537],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Associacao Redes de Desenvolvimento da Mare)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-22.864577,-43.2679478],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Voz da Comunidade)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-12.8990585,-38.4753257],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Sociedade Irmaos Solidarios)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-3.8242369,-38.5848932],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Movimento Supera Fortaleza)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-19.933662,-43.9399144],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Movimento de Luta nos Bairros, Vilas e Favelas)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-23.3262511,-51.1806254],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Prefeitura de Londrina)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-25.5065703,-49.1093529],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Acao do Bem)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-8.0931229,-34.8908352],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Livroteca Brincante do Pina)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-29.7609559,-51.1543098],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Prefeitura de Sao Leopoldo)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[2.807643,-60.684425],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Conselho Indigena de Roraima)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

fl.Marker(
    location=[-22.913594,-43.2662838],
    popup='<font color="blue"><P ALIGN=CENTER><b></font><br>(Diamantes na Cozinha)</P>',
    icon=fl.Icon(color='green'),
).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
